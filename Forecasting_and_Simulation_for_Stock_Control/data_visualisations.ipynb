# %% [markdown]
# <a href="https://colab.research.google.com/github/MQasim-Zafar/Business-Data-Analyst-Portfolio/blob/main/Forecasting_and_Simulation_for_Stock_Control_visualisations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Time series exploration

# %% [markdown]
# ### Original sales data

# %%
from google.colab import drive
from IPython.display import Image, display

drive.mount('/content/drive')

img_path = '/content/drive/MyDrive/Colab Notebooks/Forecasting and Simulation for Stock Control/visualisations/t_series_exploration/sales.png'

display(Image(filename=img_path))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ###Detrended Time Series

# %%
img_path = '/content/drive/MyDrive/Colab Notebooks/Forecasting and Simulation for Stock Control/visualisations/t_series_exploration/detrend_ts.png'

# Display the image
display(Image(filename=img_path))

# %% [markdown]
# ###Four Year Seasonal Profile

# %%
img_path = '/content/drive/MyDrive/Colab Notebooks/Forecasting and Simulation for Stock Control/visualisations/t_series_exploration/four_yr_sn.png'

# Display the image
display(Image(filename=img_path))

# %%
img_path = '/content/drive/MyDrive/Colab Notebooks/Forecasting and Simulation for Stock Control/visualisations/t_series_exploration/noise.png'

# Display the image
display(Image(filename=img_path))

# %% [markdown]
# ###Reconstructed time series

# %%
img_path = '/content/drive/MyDrive/Colab Notebooks/Forecasting and Simulation for Stock Control/visualisations/t_series_exploration/recon_ts.png'

# Display the image
display(Image(filename=img_path))

# %% [markdown]
# ##TIme Series Modeling

# %% [markdown]
# ###Simple Exponential Smoothing

# %%
img_path = '/content/drive/MyDrive/Colab Notebooks/Forecasting and Simulation for Stock Control/visualisations/t_series_modeling/s_exp_s.png'

# Display the image
display(Image(filename=img_path))

# %% [markdown]
# ###Double Exponentional Smoothing

# %%
img_path = '/content/drive/MyDrive/Colab Notebooks/Forecasting and Simulation for Stock Control/visualisations/t_series_modeling/d_exp_s.png'

# Display the image
display(Image(filename=img_path))

# %% [markdown]
# ###Triple Exponential Smoothing

# %%
img_path = '/content/drive/MyDrive/Colab Notebooks/Forecasting and Simulation for Stock Control/visualisations/t_series_modeling/t_exp_s.png'

# Display the image
display(Image(filename=img_path))

# %% [markdown]
# ###Naive Forecast

# %%
img_path = '/content/drive/MyDrive/Colab Notebooks/Forecasting and Simulation for Stock Control/visualisations/t_series_modeling/n_fc.png'

# Display the image
display(Image(filename=img_path))
